# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Crop_recommendation.csv", encoding="latin1")
data
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
# N - ratio of Nitrogen content in soil
# P - ratio of Phosphorous content in soil
# K - ratio of Potassium content in soil

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
data.head(20)
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5   69  37  42    23.058049  83.370118  7.073454  251.055000  rice
# 6   69  55  38    22.708838  82.639414  5.700806  271.324860  rice
# 7   94  53  40    20.277744  82.894086  5.718627  241.974195  rice
# 8   89  54  38    24.515881  83.535216  6.685346  230.446236  rice
# 9   68  58  38    23.223974  83.033227  6.336254  221.209196  rice
# 10  91  53  40    26.527235  81.417538  5.386168  264.614870  rice
# 11  90  46  42    23.978982  81.450616  7.502834  250.083234  rice
# 12  78  58  44    26.800796  80.886848  5.108682  284.436457  rice
# 13  93  56  36    24.014976  82.056872  6.984354  185.277339  rice
# 14  94  50  37    25.665852  80.663850  6.948020  209.586971  rice
# 15  60  48  39    24.282094  80.300256  7.042299  231.086335  rice
# 16  85  38  41    21.587118  82.788371  6.249051  276.655246  rice
# 17  91  35  39    23.793920  80.418180  6.970860  206.261186  rice
# 18  77  38  36    21.865252  80.192301  5.953933  224.555017  rice
# 19  88  35  40    23.579436  83.587603  5.853932  291.298662  rice

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='label', data=data)

plt.xticks(rotation=90)
plt.title("Crop Distribution")
plt.xlabel("Crop Type")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    data.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.title("Feature Correlation Heatmap")

plt.show()

# %%
x=data.drop("label",axis=1)
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
y=data.label
y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf.predict(x_test)
y_pred
# Out:
# array(['muskmelon', 'watermelon', 'papaya', 'papaya', 'apple', 'mango',
#        'apple', 'mothbeans', 'mungbean', 'lentil', 'blackgram', 'coconut',
#        'pomegranate', 'jute', 'coconut', 'pomegranate', 'apple', 'maize',
#        'papaya', 'muskmelon', 'coffee', 'papaya', 'orange', 'papaya',
#        'chickpea', 'jute', 'mungbean', 'orange', 'pigeonpeas', 'rice',
#        'pomegranate', 'mothbeans', 'jute', 'lentil', 'jute', 'blackgram',
#        'jute', 'chickpea', 'chickpea', 'kidneybeans', 'papaya', 'mango',
#        'blackgram', 'maize', 'mungbean', 'maize', 'pigeonpeas', 'coconut',
#        'muskmelon', 'maize', 'blackgram', 'coffee', 'grapes', 'mungbean',
#        'coffee', 'kidneybeans', 'cotton', 'apple', 'banana', 'blackgram',
#        'watermelon', 'coconut', 'lentil', 'orange', 'papaya',
#        'pigeonpeas', 'orange', 'rice', 'muskmelon', 'pigeonpeas',
#        'muskmelon', 'coconut', 'jute', 'banana', 'blackgram', 'papaya',
#        'banana', 'cotton', 'watermelon', 'orange', 'coffee', 'chickpea',
#        'rice', 'mothbeans', 'orange', 'mango', 'coffee', 'mothbeans',
#        'blackgram', 'pomegranate', 'maize', 'mothbeans', 'cotton',
#        'papaya', 'pigeonpeas', 'mothbeans', 'kidneybeans', 'coffee',
#        'blackgram', 'lentil', 'coconut', 'rice', 'orange', 'muskmelon',
#        'watermelon', 'kidneybeans', 'watermelon', 'banana', 'pigeonpeas',
#        'mothbeans', 'banana', 'jute', 'cotton', 'pomegranate',
#        'pigeonpeas', 'chickpea', 'maize', 'coconut', 'pomegranate',
#        'rice', 'pigeonpeas', 'grapes', 'blackgram', 'coconut', 'chickpea',
#        'blackgram', 'coconut', 'maize', 'banana', 'mothbeans', 'banana',
#        'kidneybeans', 'pomegranate', 'chickpea', 'coconut', 'orange',
#        'pigeonpeas', 'banana', 'banana', 'apple', 'kidneybeans',
#        'muskmelon', 'mungbean', 'mothbeans', 'coconut', 'maize', 'apple',
#        'coconut', 'kidneybeans', 'mothbeans', 'mungbean', 'lentil',
#        'watermelon', 'mungbean', 'pigeonpeas', 'pigeonpeas', 'pigeonpeas',
#        'kidneybeans', 'maize', 'jute', 'chickpea', 'apple', 'orange',
#        'cotton', 'rice', 'coconut', 'grapes', 'lentil', 'watermelon',
#        'grapes', 'grapes', 'blackgram', 'pomegranate', 'chickpea',
#        'coconut', 'maize', 'lentil', 'grapes', 'watermelon', 'jute',
#        'coffee', 'coffee', 'kidneybeans', 'jute', 'mothbeans',
#        'kidneybeans', 'banana', 'kidneybeans', 'coconut', 'papaya',
#        'papaya', 'mungbean', 'mango', 'pomegranate', 'watermelon',
#        'kidneybeans', 'maize', 'apple', 'blackgram', 'chickpea', 'grapes',
#        'grapes', 'banana', 'cotton', 'rice', 'pomegranate', 'mungbean',
#        'banana', 'jute', 'mungbean', 'maize', 'chickpea', 'chickpea',
#        'chickpea', 'apple', 'rice', 'kidneybeans', 'papaya', 'coffee',
#        'blackgram', 'kidneybeans', 'mango', 'mango', 'coconut', 'papaya',
#        'apple', 'chickpea', 'pomegranate', 'chickpea', 'muskmelon',
#        'apple', 'muskmelon', 'muskmelon', 'mango', 'mango', 'cotton',
#        'coconut', 'pomegranate', 'rice', 'muskmelon', 'coffee', 'papaya',
#        'mothbeans', 'maize', 'mango', 'muskmelon', 'pigeonpeas',
#        'mungbean', 'coffee', 'grapes', 'coconut', 'cotton', 'pigeonpeas',
#        'rice', 'apple', 'pomegranate', 'coffee', 'chickpea', 'cotton',
#        'jute', 'mango', 'banana', 'papaya', 'apple', 'chickpea', 'rice',
#        'pigeonpeas', 'mothbeans', 'mungbean', 'jute', 'pomegranate',
#        'grapes', 'mothbeans', 'jute', 'maize', 'coconut', 'maize',
#        'chickpea', 'banana', 'jute', 'coconut', 'jute', 'mango',
#        'muskmelon', 'apple', 'banana', 'pigeonpeas', 'blackgram',
#        'orange', 'chickpea', 'watermelon', 'banana', 'apple', 'chickpea',
#        'coffee', 'pigeonpeas', 'orange', 'apple', 'coconut', 'papaya',
#        'watermelon', 'mothbeans', 'papaya', 'chickpea', 'pomegranate',
#        'chickpea', 'papaya', 'lentil', 'apple', 'pomegranate', 'chickpea',
#        'mango', 'chickpea', 'pomegranate', 'watermelon', 'kidneybeans',
#        'mungbean', 'muskmelon', 'watermelon', 'kidneybeans', 'muskmelon',
#        'mango', 'jute', 'blackgram', 'chickpea', 'banana', 'blackgram',
#        'pigeonpeas', 'papaya', 'pigeonpeas', 'mungbean', 'coconut',
#        'cotton', 'grapes', 'apple', 'lentil', 'banana', 'jute', 'apple',
#        'pomegranate', 'apple', 'mungbean', 'muskmelon', 'coffee',
#        'coffee', 'pigeonpeas', 'jute', 'kidneybeans', 'banana', 'maize',
#        'jute', 'maize', 'pigeonpeas', 'mango', 'kidneybeans',
#        'pomegranate', 'watermelon', 'blackgram', 'maize', 'rice',
#        'mothbeans', 'kidneybeans', 'mango', 'cotton', 'papaya',
#        'mothbeans', 'cotton', 'mungbean', 'orange', 'jute', 'blackgram',
#        'mungbean', 'coffee', 'banana', 'pigeonpeas', 'papaya', 'apple',
#        'pomegranate', 'maize', 'mango', 'coconut', 'apple', 'lentil',
#        'jute', 'mothbeans', 'lentil', 'coconut', 'blackgram', 'jute',
#        'mungbean', 'cotton', 'watermelon', 'apple', 'grapes', 'coconut',
#        'grapes', 'watermelon', 'rice', 'mango', 'mango', 'coffee',
#        'pomegranate', 'banana', 'grapes', 'jute', 'orange', 'cotton',
#        'mango', 'papaya', 'muskmelon', 'mothbeans', 'jute', 'chickpea',
#        'mothbeans', 'pomegranate', 'watermelon', 'mothbeans', 'cotton',
#        'papaya', 'watermelon', 'lentil', 'rice', 'coconut', 'mothbeans',
#        'mothbeans', 'maize', 'rice', 'maize', 'coconut', 'orange',
#        'pomegranate', 'kidneybeans', 'watermelon', 'mungbean',
#        'blackgram', 'rice', 'rice', 'cotton', 'cotton', 'pigeonpeas'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9931818181818182

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       1.00      1.00      1.00        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       1.00      1.00      1.00        17
#       cotton       1.00      1.00      1.00        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.92      1.00      0.96        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.92      1.00      0.96        11
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      0.96      0.98        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
#       orange       1.00      1.00      1.00        14
#       papaya       1.00      1.00      1.00        23
#   pigeonpeas       1.00      1.00      1.00        23
#  pomegranate       1.00      1.00      1.00        23
#         rice       1.00      0.89      0.94        19
#   watermelon       1.00      1.00      1.00        19
#
#     accuracy                           0.99       440
#    macro avg       0.99      0.99      0.99       440
# weighted avg       0.99      0.99      0.99       440

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn.predict(x_test)
y_pred_knn
# Out:
# array(['muskmelon', 'watermelon', 'papaya', 'papaya', 'apple', 'mango',
#        'apple', 'mothbeans', 'mungbean', 'lentil', 'blackgram', 'coconut',
#        'pomegranate', 'jute', 'coconut', 'pomegranate', 'apple', 'cotton',
#        'papaya', 'muskmelon', 'coffee', 'papaya', 'orange', 'papaya',
#        'chickpea', 'jute', 'mungbean', 'orange', 'pigeonpeas', 'jute',
#        'pomegranate', 'mothbeans', 'jute', 'lentil', 'jute', 'blackgram',
#        'jute', 'chickpea', 'chickpea', 'kidneybeans', 'papaya', 'mango',
#        'blackgram', 'maize', 'mungbean', 'maize', 'pigeonpeas', 'coconut',
#        'muskmelon', 'maize', 'blackgram', 'coffee', 'grapes', 'mungbean',
#        'coffee', 'kidneybeans', 'cotton', 'apple', 'banana', 'blackgram',
#        'watermelon', 'coconut', 'lentil', 'orange', 'papaya', 'blackgram',
#        'orange', 'rice', 'muskmelon', 'pigeonpeas', 'muskmelon',
#        'coconut', 'jute', 'banana', 'blackgram', 'papaya', 'banana',
#        'cotton', 'watermelon', 'orange', 'coffee', 'chickpea', 'jute',
#        'mothbeans', 'orange', 'mango', 'coffee', 'mothbeans', 'blackgram',
#        'pomegranate', 'maize', 'mothbeans', 'cotton', 'papaya',
#        'pigeonpeas', 'mothbeans', 'kidneybeans', 'coffee', 'blackgram',
#        'lentil', 'coconut', 'jute', 'orange', 'muskmelon', 'watermelon',
#        'kidneybeans', 'watermelon', 'banana', 'pigeonpeas', 'mothbeans',
#        'banana', 'jute', 'cotton', 'pomegranate', 'pigeonpeas',
#        'chickpea', 'maize', 'coconut', 'pomegranate', 'rice',
#        'pigeonpeas', 'grapes', 'blackgram', 'coconut', 'chickpea',
#        'blackgram', 'coconut', 'maize', 'banana', 'mothbeans', 'banana',
#        'kidneybeans', 'pomegranate', 'chickpea', 'coconut', 'orange',
#        'pigeonpeas', 'banana', 'banana', 'apple', 'kidneybeans',
#        'muskmelon', 'mungbean', 'mothbeans', 'coconut', 'maize', 'apple',
#        'coconut', 'kidneybeans', 'mothbeans', 'mungbean', 'lentil',
#        'watermelon', 'mungbean', 'pigeonpeas', 'pigeonpeas', 'pigeonpeas',
#        'kidneybeans', 'maize', 'jute', 'chickpea', 'apple', 'orange',
#        'cotton', 'rice', 'coconut', 'grapes', 'lentil', 'watermelon',
#        'grapes', 'grapes', 'blackgram', 'pomegranate', 'chickpea',
#        'coconut', 'maize', 'lentil', 'grapes', 'watermelon', 'jute',
#        'coffee', 'coffee', 'kidneybeans', 'jute', 'mothbeans',
#        'kidneybeans', 'banana', 'kidneybeans', 'coconut', 'papaya',
#        'papaya', 'mungbean', 'mango', 'pomegranate', 'watermelon',
#        'kidneybeans', 'maize', 'apple', 'blackgram', 'chickpea', 'grapes',
#        'grapes', 'banana', 'cotton', 'rice', 'pomegranate', 'mungbean',
#        'banana', 'jute', 'mungbean', 'maize', 'chickpea', 'chickpea',
#        'chickpea', 'apple', 'rice', 'kidneybeans', 'papaya', 'coffee',
#        'blackgram', 'kidneybeans', 'mango', 'mango', 'coconut', 'papaya',
#        'apple', 'chickpea', 'pomegranate', 'chickpea', 'muskmelon',
#        'apple', 'muskmelon', 'muskmelon', 'mango', 'mango', 'cotton',
#        'coconut', 'pomegranate', 'rice', 'muskmelon', 'coffee', 'papaya',
#        'lentil', 'maize', 'mango', 'muskmelon', 'pigeonpeas', 'mungbean',
#        'coffee', 'grapes', 'coconut', 'cotton', 'pigeonpeas', 'rice',
#        'apple', 'pomegranate', 'coffee', 'chickpea', 'cotton', 'jute',
#        'mango', 'banana', 'papaya', 'apple', 'chickpea', 'jute',
#        'pigeonpeas', 'mothbeans', 'mungbean', 'jute', 'pomegranate',
#        'grapes', 'mothbeans', 'jute', 'maize', 'coconut', 'maize',
#        'chickpea', 'banana', 'jute', 'coconut', 'jute', 'mango',
#        'muskmelon', 'apple', 'banana', 'pigeonpeas', 'blackgram',
#        'orange', 'chickpea', 'watermelon', 'banana', 'apple', 'chickpea',
#        'coffee', 'pigeonpeas', 'orange', 'apple', 'coconut', 'papaya',
#        'watermelon', 'mothbeans', 'papaya', 'chickpea', 'pomegranate',
#        'chickpea', 'papaya', 'lentil', 'apple', 'pomegranate', 'chickpea',
#        'mango', 'chickpea', 'pomegranate', 'watermelon', 'kidneybeans',
#        'mungbean', 'muskmelon', 'watermelon', 'kidneybeans', 'muskmelon',
#        'mango', 'jute', 'blackgram', 'chickpea', 'banana', 'blackgram',
#        'pigeonpeas', 'papaya', 'kidneybeans', 'mungbean', 'coconut',
#        'cotton', 'grapes', 'apple', 'lentil', 'banana', 'jute', 'apple',
#        'pomegranate', 'apple', 'mungbean', 'muskmelon', 'coffee', 'jute',
#        'pigeonpeas', 'jute', 'kidneybeans', 'banana', 'maize', 'jute',
#        'maize', 'pigeonpeas', 'mango', 'kidneybeans', 'pomegranate',
#        'watermelon', 'blackgram', 'maize', 'rice', 'mothbeans',
#        'kidneybeans', 'mango', 'cotton', 'papaya', 'mothbeans', 'cotton',
#        'mungbean', 'orange', 'rice', 'blackgram', 'mungbean', 'coffee',
#        'banana', 'pigeonpeas', 'papaya', 'apple', 'pomegranate', 'maize',
#        'mango', 'coconut', 'apple', 'lentil', 'jute', 'mothbeans',
#        'lentil', 'coconut', 'blackgram', 'jute', 'mungbean', 'cotton',
#        'watermelon', 'apple', 'grapes', 'coconut', 'grapes', 'watermelon',
#        'rice', 'mango', 'mango', 'coffee', 'pomegranate', 'banana',
#        'grapes', 'jute', 'orange', 'cotton', 'mango', 'papaya',
#        'muskmelon', 'mothbeans', 'jute', 'chickpea', 'mothbeans',
#        'pomegranate', 'watermelon', 'mothbeans', 'cotton', 'papaya',
#        'watermelon', 'lentil', 'rice', 'coconut', 'mothbeans',
#        'mothbeans', 'maize', 'rice', 'maize', 'coconut', 'orange',
#        'pomegranate', 'kidneybeans', 'watermelon', 'mungbean',
#        'blackgram', 'rice', 'rice', 'cotton', 'cotton', 'pigeonpeas'],
#       dtype=object)

# %%
print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.9704545454545455

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt = dt.predict(x_test)
y_pred_dt
# Out:
# array(['muskmelon', 'watermelon', 'papaya', 'papaya', 'apple', 'mango',
#        'apple', 'mothbeans', 'mungbean', 'lentil', 'blackgram', 'coconut',
#        'pomegranate', 'jute', 'coconut', 'pomegranate', 'apple', 'maize',
#        'papaya', 'muskmelon', 'coffee', 'papaya', 'orange', 'papaya',
#        'chickpea', 'jute', 'mungbean', 'orange', 'pigeonpeas', 'rice',
#        'pomegranate', 'mothbeans', 'jute', 'lentil', 'jute', 'blackgram',
#        'jute', 'chickpea', 'chickpea', 'kidneybeans', 'papaya', 'mango',
#        'blackgram', 'maize', 'mungbean', 'maize', 'pigeonpeas', 'coconut',
#        'muskmelon', 'maize', 'blackgram', 'coffee', 'grapes', 'mungbean',
#        'coffee', 'kidneybeans', 'cotton', 'apple', 'banana', 'blackgram',
#        'watermelon', 'coconut', 'lentil', 'orange', 'papaya',
#        'pigeonpeas', 'orange', 'rice', 'muskmelon', 'pigeonpeas',
#        'muskmelon', 'coconut', 'jute', 'banana', 'blackgram', 'papaya',
#        'banana', 'cotton', 'watermelon', 'orange', 'coffee', 'chickpea',
#        'rice', 'mothbeans', 'orange', 'mango', 'coffee', 'mothbeans',
#        'blackgram', 'pomegranate', 'maize', 'mothbeans', 'cotton',
#        'papaya', 'pigeonpeas', 'mothbeans', 'kidneybeans', 'coffee',
#        'blackgram', 'lentil', 'coconut', 'rice', 'orange', 'muskmelon',
#        'watermelon', 'kidneybeans', 'watermelon', 'banana', 'pigeonpeas',
#        'mothbeans', 'banana', 'jute', 'cotton', 'pomegranate',
#        'pigeonpeas', 'chickpea', 'maize', 'coconut', 'pomegranate',
#        'rice', 'pigeonpeas', 'grapes', 'blackgram', 'coconut', 'chickpea',
#        'blackgram', 'coconut', 'maize', 'banana', 'mothbeans', 'banana',
#        'kidneybeans', 'pomegranate', 'chickpea', 'coconut', 'orange',
#        'pigeonpeas', 'banana', 'banana', 'apple', 'kidneybeans',
#        'muskmelon', 'mungbean', 'mothbeans', 'coconut', 'coconut',
#        'apple', 'coconut', 'kidneybeans', 'blackgram', 'mungbean',
#        'lentil', 'watermelon', 'mungbean', 'pigeonpeas', 'pigeonpeas',
#        'pigeonpeas', 'kidneybeans', 'maize', 'jute', 'chickpea', 'apple',
#        'orange', 'cotton', 'rice', 'coconut', 'grapes', 'lentil',
#        'watermelon', 'grapes', 'grapes', 'blackgram', 'pomegranate',
#        'chickpea', 'coconut', 'maize', 'lentil', 'grapes', 'watermelon',
#        'jute', 'coffee', 'coffee', 'kidneybeans', 'jute', 'mothbeans',
#        'kidneybeans', 'banana', 'kidneybeans', 'coconut', 'papaya',
#        'papaya', 'mungbean', 'mango', 'pomegranate', 'watermelon',
#        'kidneybeans', 'maize', 'apple', 'blackgram', 'chickpea', 'grapes',
#        'grapes', 'banana', 'cotton', 'rice', 'pomegranate', 'mungbean',
#        'banana', 'jute', 'mungbean', 'maize', 'chickpea', 'chickpea',
#        'chickpea', 'apple', 'rice', 'kidneybeans', 'papaya', 'coffee',
#        'blackgram', 'kidneybeans', 'mango', 'mango', 'coconut', 'papaya',
#        'apple', 'chickpea', 'pomegranate', 'chickpea', 'muskmelon',
#        'apple', 'muskmelon', 'muskmelon', 'mango', 'mango', 'cotton',
#        'coconut', 'pomegranate', 'rice', 'muskmelon', 'coffee', 'papaya',
#        'mothbeans', 'maize', 'mango', 'muskmelon', 'pigeonpeas',
#        'mungbean', 'coffee', 'grapes', 'coconut', 'cotton', 'pigeonpeas',
#        'rice', 'apple', 'pomegranate', 'coffee', 'chickpea', 'cotton',
#        'jute', 'mango', 'banana', 'papaya', 'apple', 'chickpea', 'rice',
#        'pigeonpeas', 'mothbeans', 'mungbean', 'jute', 'pomegranate',
#        'grapes', 'mothbeans', 'jute', 'maize', 'coconut', 'maize',
#        'chickpea', 'banana', 'jute', 'coconut', 'jute', 'mango',
#        'muskmelon', 'apple', 'banana', 'pigeonpeas', 'blackgram',
#        'orange', 'chickpea', 'watermelon', 'banana', 'apple', 'chickpea',
#        'coffee', 'pigeonpeas', 'orange', 'apple', 'coconut', 'papaya',
#        'watermelon', 'mothbeans', 'papaya', 'chickpea', 'pomegranate',
#        'chickpea', 'papaya', 'lentil', 'apple', 'pomegranate', 'chickpea',
#        'mango', 'chickpea', 'pomegranate', 'watermelon', 'kidneybeans',
#        'mungbean', 'muskmelon', 'watermelon', 'kidneybeans', 'muskmelon',
#        'mango', 'jute', 'blackgram', 'chickpea', 'banana', 'blackgram',
#        'pigeonpeas', 'papaya', 'pigeonpeas', 'mungbean', 'coconut',
#        'cotton', 'grapes', 'apple', 'lentil', 'banana', 'jute', 'apple',
#        'pomegranate', 'apple', 'mungbean', 'muskmelon', 'coffee',
#        'coffee', 'pigeonpeas', 'jute', 'kidneybeans', 'banana', 'maize',
#        'jute', 'maize', 'pigeonpeas', 'mango', 'kidneybeans',
#        'pomegranate', 'watermelon', 'blackgram', 'maize', 'rice',
#        'mothbeans', 'kidneybeans', 'mango', 'cotton', 'papaya',
#        'mothbeans', 'cotton', 'mungbean', 'orange', 'rice', 'blackgram',
#        'mungbean', 'coffee', 'banana', 'pigeonpeas', 'papaya', 'apple',
#        'pomegranate', 'maize', 'mango', 'coconut', 'apple', 'lentil',
#        'jute', 'mothbeans', 'lentil', 'coconut', 'blackgram', 'jute',
#        'mungbean', 'cotton', 'watermelon', 'apple', 'grapes', 'coconut',
#        'grapes', 'watermelon', 'rice', 'mango', 'mango', 'coffee',
#        'pomegranate', 'banana', 'grapes', 'jute', 'orange', 'cotton',
#        'mango', 'papaya', 'muskmelon', 'mothbeans', 'jute', 'chickpea',
#        'mothbeans', 'pomegranate', 'watermelon', 'mothbeans', 'cotton',
#        'papaya', 'watermelon', 'lentil', 'rice', 'coconut', 'mothbeans',
#        'mothbeans', 'maize', 'rice', 'maize', 'coconut', 'orange',
#        'pomegranate', 'kidneybeans', 'watermelon', 'mungbean',
#        'blackgram', 'rice', 'rice', 'cotton', 'cotton', 'pigeonpeas'],
#       dtype=object)

# %%
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.9863636363636363

# %%
import numpy as np

input_data = (90, 42, 43, 20.5, 80, 6.5, 200)

# Convert input data to a numpy array
input_data_as_numpy_array = np.array(input_data)
#Machine learning models prefer arrays instead of tuples or lists.

# Reshape the data as we're predicting for one instance
input_data_reshape = input_data_as_numpy_array.reshape(1, -1)   

# Make prediction using your trained model
prediction = rf.predict(input_data_reshape)

print("Recommended Crop:", prediction[0])
# Out:
# Recommended Crop: rice

# %%
import pickle

# %%
filename='crop_project_model.sav'
pickle.dump(rf,open(filename,'wb'))
loaded_model=pickle.load(open(filename,"rb"))
loaded_model
# Out:
# RandomForestClassifier(random_state=42)

# %%
import gradio as gr
import pickle 
import numpy as np

# %%
! pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\ananthu\anaconda3\lib\site-packages (6.5.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.128.1)
# Requirement already satisfied: ffmpy in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.3 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.0.3)
# Requirement already satisfied: groovy~=0.1 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (1.14.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (3.11.7)
# Requirement already satisfied: packaging in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.10.3)
# Requirement already satisfied: pydub in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.0.22)
# Requirement already satisfied: pytz>=2017.2 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2024.1)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.21.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.40.0)
# Requirement already satisfied: fsspec in c:\users\ananthu\anaconda3\lib\site-packages (from gradio-client==2.0.3->gradio) (2025.3.2)
# Requirement already satisfied: idna>=2.8 in c:\users\ananthu\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ananthu\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\ananthu\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\ananthu\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ananthu\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ananthu\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\ananthu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.17.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\ananthu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ananthu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ananthu\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ananthu\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ananthu\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ananthu\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\ananthu\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ananthu\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ananthu\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\ananthu\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ananthu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ananthu\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ananthu\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ananthu\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\ananthu\anaconda3\lib\site-packages (6.5.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.128.1)
# Requirement already satisfied: ffmpy in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.3 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.0.3)
# Requirement already satisfied: groovy~=0.1 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (1.14.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (3.11.7)
# Requirement already satisfied: packaging in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.10.3)
# Requirement already satisfied: pydub in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.0.22)
# Requirement already satisfied: pytz>=2017.2 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2024.1)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.21.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\ananthu\anaconda3\lib\site-packages (from gradio) (0.40.0)
# Requirement already satisfied: fsspec in c:\users\ananthu\anaconda3\lib\site-packages (from gradio-client==2.0.3->gradio) (2025.3.2)
# Requirement already satisfied: idna>=2.8 in c:\users\ananthu\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ananthu\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\ananthu\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\ananthu\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ananthu\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ananthu\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\ananthu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.17.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\ananthu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ananthu\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ananthu\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ananthu\anaconda3\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ananthu\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ananthu\anaconda3\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\ananthu\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ananthu\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ananthu\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\ananthu\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ananthu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ananthu\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ananthu\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ananthu\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle

pickle.dump(rf, open("crop_model.pkl", "wb"))

# %%
import gradio as gr
import numpy as np
import pickle

# Load model
model = pickle.load(open("crop_model.pkl", "rb"))

# Prediction Function
def predict_crop(N, P, K, temperature, humidity, ph, rainfall):

    # Convert input into NumPy array
    data = np.array([[N, P, K, temperature, humidity, ph, rainfall]])

    # Predict crop
    prediction = model.predict(data)

    # Return result
    return f"Recommended Crop: {prediction[0]}"

# Gradio Interface
interface = gr.Interface(

    fn=predict_crop,

    inputs=[
        gr.Number(label="Nitrogen (N)"),
        gr.Number(label="Phosphorus (P)"),
        gr.Number(label="Potassium (K)"),
        gr.Number(label="Temperature"),
        gr.Number(label="Humidity"),
        gr.Number(label="pH"),
        gr.Number(label="Rainfall")
    ],

    outputs=gr.Textbox(label="Output"),

    title="🌱 Crop Recommendation System",

    description="Enter soil and environmental values to predict the best crop."
)

# Launch
interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
